# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import os
import re
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import string
from collections import defaultdict
from nltk.stem.porter import PorterStemmer
import pickle
from IPython.display import clear_output
from gensim import corpora, models
from gensim.models import Phrases, Word2Vec
from gensim.models.phrases import Phraser
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
funded_R01_projects_unique_dropped = pd.read_csv("data/funded_R01_projects_category.csv")
# Out:
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,12,13,16,20,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
funded_R01_projects_unique_dropped.head()
# Out:
#    Unnamed: 0  APPLICATION_ID ARRA_FUNDED    AWARD_NOTICE_DATE  BUDGET_END  \
# 0        2185         7499670         NaN  2008-09-12T00:00:00  08/31/2009
# 1        2186         7495989         NaN  2008-09-16T00:00:00  06/30/2009
# 2        2187         7502303         NaN  2008-09-01T00:00:00  06/30/2009
# 3        2188         7501548         NaN  2008-06-30T00:00:00  06/30/2009
# 4        2189         7439671         NaN  2008-08-16T00:00:00  05/31/2009
#
#   BUDGET_START  CFDA_CODE CORE_PROJECT_NUM  DIRECT_COST_AMT  \
# 0   09/01/2008      389.0      U24RR018107              NaN
# 1   09/01/2008      389.0      U24RR018108              NaN
# 2   09/01/2008      389.0      U24RR018109              NaN
# 3   07/01/2008      389.0      U24RR018111              NaN
# 4   08/18/2008      389.0      U24RR018144              NaN
#
#           ED_INST_TYPE     ...      SUFFIX TOTAL_COST TOTAL_COST_SUB_PROJECT  \
# 0  SCHOOLS OF MEDICINE     ...         NaN   741430.0                    NaN
# 1      UNIVERSITY-WIDE     ...         NaN  1811959.0                    NaN
# 2      PRIMATE CENTERS     ...          A1  1431792.0                    NaN
# 3      PRIMATE CENTERS     ...          A1  1908805.0                    NaN
# 4      PRIMATE CENTERS     ...         NaN  2067808.0                    NaN
#
#                                        ABSTRACT_TEXT    grant_num  \
# 0    [unreadable] DESCRIPTION (provided by applic...  U24RR018107
# 1    [unreadable] DESCRIPTION (provided by applic...  U24RR018108
# 2    [unreadable] DESCRIPTION (provided by applic...  U24RR018109
# 3    [unreadable] DESCRIPTION (provided by applic...  U24RR018111
# 4    [unreadable] DESCRIPTION (provided by applic...  U24RR018144
#
#    topics_proj_terms topics_spending_cats topics_total      category  \
# 0                 []                   []           []  Tuberculosis
# 1                 []                   []           []  Tuberculosis
# 2                 []                   []           []  Tuberculosis
# 3                 []                   []           []  Tuberculosis
# 4                 []                   []           []  Tuberculosis
#
#    probability
# 0     1.000000
# 1     0.999931
# 2     0.999549
# 3     1.000000
# 4     0.999975
#
# [5 rows x 44 columns]

# %%
len(funded_R01_projects_unique_dropped)
# Out:
# 272098

# %%
funded_projects = pd.DataFrame()
for root, dirs, files in os.walk("data/completed_full_csv_parts/", topdown=True):
    for file in files:
        df = pd.read_csv(os.path.join(root, file))
        funded_projects = funded_projects.append(df)
# Out:
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,5,11,12,15,17,19,23,24,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,12,19,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,11,12,15,19,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,12,15,19,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,11,12,15,19,24,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/maheshrao/anaconda3/envs/capstone/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,3,4,8,9,11,12,15,17,19,23,24,26,28,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
funded_R01_projects = funded_projects[funded_projects.grant_num.str.contains("R01")]

# %%
funded_R01_projects_complete = funded_R01_projects.merge(funded_R01_projects_unique_dropped[["ABSTRACT_TEXT", "category", "probability"]], how = "left", on = "ABSTRACT_TEXT")

# %%
print(len(funded_R01_projects), len(funded_R01_projects_unique_dropped), len(funded_R01_projects_complete))
# Out:
# 645439 272098 645439

# %%
funded_R01_projects_complete
# Out:
#         APPLICATION_ID ARRA_FUNDED    AWARD_NOTICE_DATE  BUDGET_END  \
# 0              7499670         NaN  2008-09-12T00:00:00  08/31/2009
# 1              7495989         NaN  2008-09-16T00:00:00  06/30/2009
# 2              7502303         NaN  2008-09-01T00:00:00  06/30/2009
# 3              7501548         NaN  2008-06-30T00:00:00  06/30/2009
# 4              7439671         NaN  2008-08-16T00:00:00  05/31/2009
# 5              7417544         NaN  2008-04-30T00:00:00  04/30/2010
# 6              7667600         NaN  2008-09-16T00:00:00  04/30/2010
# 7              7725973         NaN  2008-04-30T00:00:00  04/30/2009
# 8              7725974         NaN  2008-04-30T00:00:00  04/30/2009
# 9              7725975         NaN  2008-04-30T00:00:00  04/30/2009
# 10             7482232         NaN  2008-08-14T00:00:00  07/31/2009
# 11             7719651         NaN  2008-08-14T00:00:00  07/31/2009
# 12             7719652         NaN  2008-08-14T00:00:00  07/31/2009
# 13             7719653         NaN  2008-08-14T00:00:00  07/31/2009
# 14             7719654         NaN  2008-08-14T00:00:00  07/31/2009
# 15             7719655         NaN  2008-08-14T00:00:00  07/31/2009
# 16             7719656         NaN  2008-08-14T00:00:00  07/31/2009
# 17             7719657         NaN  2008-08-14T00:00:00  07/31/2009
# 18             7719658         NaN  2008-08-14T00:00:00  07/31/2009
# 19             7719659         NaN  2008-08-14T00:00:00  07/31/2009
# 20             7719660         NaN  2008-08-14T00:00:00  07/31/2009
# 21             7719661         NaN  2008-08-14T00:00:00  07/31/2009
# 22             7719662         NaN  2008-08-14T00:00:00  07/31/2009
# 23             7719663         NaN  2008-08-14T00:00:00  07/31/2009
# 24             7719664         NaN  2008-08-14T00:00:00  07/31/2009
# 25             7719665         NaN  2008-08-14T00:00:00  07/31/2009
# 26             7719666         NaN  2008-08-14T00:00:00  07/31/2009
# 27             7719667         NaN  2008-08-14T00:00:00  07/31/2009
# 28             7719668         NaN  2008-08-14T00:00:00  07/31/2009
# 29             7684542         NaN  2008-09-12T00:00:00  02/28/2009
# ...                ...         ...                  ...         ...
# 645409         7903250           N                  NaN  06/30/2010
# 645410         7903251           N                  NaN  06/30/2010
# 645411         7880935           N                  NaN  06/30/2010
# 645412         7880936           N                  NaN  06/30/2010
# 645413         7880937           N                  NaN  06/30/2010
# 645414         7886516           N                  NaN  06/30/2010
# 645415         7886517           N                  NaN  06/30/2010
# 645416         7886518           N                  NaN  06/30/2010
# 645417         7880150           N                  NaN  06/30/2010
# 645418         7880151           N                  NaN  06/30/2010
# 645419         7546904         NaN                  NaN         NaN
# 645420         7546906         NaN                  NaN         NaN
# 645421         7546907         NaN                  NaN         NaN
# 645422         7546909         NaN                  NaN         NaN
# 645423         7546912         NaN                  NaN         NaN
# 645421          NaN       NaN      P01NR010948              NaN
# 645422          NaN       NaN      P01NR010948              NaN
# 645423          NaN       NaN      P01NR010949              NaN
# 645424          NaN       NaN      P01NR010949              NaN
# 645425          NaN       NaN      P01NR010949              NaN
# 645426          NaN       NaN      P01NR010949              NaN
# 645427          NaN       NaN      P01NR010949              NaN
# 645428   07/01/2008       NaN      P20NR010671              NaN
# 645429   07/01/2008       NaN      P20NR010679              NaN
# 645430   07/01/2008       NaN      P20NR010679              NaN
# 645431   07/01/2008       NaN      P30NR010676              NaN
# 645432   07/01/2008       NaN      P30NR010676              NaN
# 645433   07/01/2008       NaN      P30NR010676              NaN
# 645434   07/01/2008       NaN      P30NR010677              NaN
# 645435   07/01/2008       NaN      P30NR010677              NaN
# 645436   07/01/2008       NaN      P30NR010677              NaN
# 645437   07/01/2008       NaN      P30NR010680              NaN
# 645438   07/01/2008       NaN      P30NR010680              NaN
#
#                ED_INST_TYPE     FOA_NUMBER     ...      \
# 0       SCHOOLS OF MEDICINE            NaN     ...
# 1           UNIVERSITY-WIDE            NaN     ...
# 2           PRIMATE CENTERS            NaN     ...
# 3           PRIMATE CENTERS            NaN     ...
# 4           PRIMATE CENTERS            NaN     ...
# 5       SCHOOLS OF MEDICINE            NaN     ...
# 6       SCHOOLS OF MEDICINE            NaN     ...
# 7       SCHOOLS OF MEDICINE            NaN     ...
# 8       SCHOOLS OF MEDICINE            NaN     ...
# 9       SCHOOLS OF MEDICINE            NaN     ...
# 10                      NaN            NaN     ...
# 11                      NaN            NaN     ...
# 12                      NaN            NaN     ...
# 13                      NaN            NaN     ...
# 14                      NaN            NaN     ...
# 15                      NaN            NaN     ...
# 16                      NaN            NaN     ...
# 17                      NaN            NaN     ...
# 18                      NaN            NaN     ...
# 19                      NaN            NaN     ...
# 20                      NaN            NaN     ...
# 21                      NaN            NaN     ...
# 22                      NaN            NaN     ...
# 23                      NaN            NaN     ...
# 24                      NaN            NaN     ...
# 25                      NaN            NaN     ...
# 26                      NaN            NaN     ...
# 27                      NaN            NaN     ...
# 28                      NaN            NaN     ...
# 29      SCHOOLS OF MEDICINE            NaN     ...
# ...                     ...            ...     ...
# 645409                  NaN  RFA-NR-07-004     ...
# 645410                  NaN  RFA-NR-07-004     ...
# 645411                  NaN  RFA-NR-07-005     ...
# 645412                  NaN  RFA-NR-07-005     ...
# 645413                  NaN  RFA-NR-07-005     ...
# 645414                  NaN  RFA-NR-07-005     ...
# 645415                  NaN  RFA-NR-07-005     ...
# 645416                  NaN  RFA-NR-07-005     ...
# 645417                  NaN  RFA-NR-07-005     ...
# 645418                  NaN  RFA-NR-07-005     ...
# 645419                  NaN            NaN     ...
# 645420                  NaN            NaN     ...
# 645421                  NaN            NaN     ...
# 645422                  NaN            NaN     ...
# 645423                  NaN            NaN     ...
# 645424                  NaN            NaN     ...
# 645425                  NaN            NaN     ...
# 645426                  NaN            NaN     ...
# 645427                  NaN            NaN     ...
# 645428                  NaN            NaN     ...
# 645429                  NaN            NaN     ...
# 645430                  NaN            NaN     ...
# 645431                  NaN            NaN     ...
# 645432                  NaN            NaN     ...
# 645433                  NaN            NaN     ...
# 645434                  NaN            NaN     ...
# 645435                  NaN            NaN     ...
# 645436                  NaN            NaN     ...
# 645437                  NaN            NaN     ...
# 645438                  NaN            NaN     ...
#
#                                             PROJECT_TITLE STUDY_SECTION  \
# 0       ESTABLISHMENT OF SPECIFIC PATHOGEN FREE RHESUS...          RIRG
# 1       ENHANCEMENT OF THE CPRC-SPF RHESUS MONKEY PROGRAM          RIRG
# 2                SPF Breeding Colonies at the Yerkes NPRC          RIRG
# 3        Establishment and Expansion of SPF Rhesus Colony          RIRG
# 4       Genetically Defined Herpes/Retrovirus SPF Maca...          RIRG
# 5                     BIOMEDICAL IMAGING RESEARCH NETWORK          ZRR1
# 6                     BIOMEDICAL IMAGING RESEARCH NETWORK          ZRR1
# 7       BIOMEDICAL INFORMATICS RESEARCH NETWORK: NEURO...          ZRR1
# 8       BIOMEDICAL INFORMATICS RESEARCH NETWORK: NATIO...          ZRR1
# 9       BIOMEDICAL IMAGING RESEARCH NETWORK: NEUROLOGI...          ZRR1
# 10                            IMAGE GUIDED THERAPY CENTER          ZRG1
# 11                                     COMPUTATIONAL CORE          ZRG1
# 12               IMAGING METHODS FOR IMAGE GUIDED THERAPY          ZRG1
# 13                                          PROSTATE CORE          ZRG1
# 14                                      NEUROSURGERY CORE          ZRG1
# 15                                FOCUSED ULTRASOUND CORE          ZRG1
# 16      OPENING THE BLOOD BRAIN BARRIER FOR MOLECULAR ...          ZRG1
# 17                                      MR GUIDED THERAPY          ZRG1
# 18      TARGETED PROSTATE BIOPSY USING MATHEMATICAL OP...          ZRG1
# 19      NOVEL MRI CONTRAST AGENT FOR MONITORING THERMA...          ZRG1
# 20             SHEAR-MODE TRANSCRANIAL ULTRASOUND IMAGING          ZRG1
# 21      IMPROVED SPACIAL LOCALIZATION FOR SPECTROSCOPI...          ZRG1
# 22      MR GUIDED FOCUSED ULTRASOUND SURGERY FOR PROST...          ZRG1
# 23       ADMINISTRATION CORE - TRAINING AND DISSEMINATION          ZRG1
# 24                          ADMINISTRATION CORE - SERVICE          ZRG1
# 25      ENABLING TECHNOLOGIES FOR MRI-GUIDED PROSTATE ...          ZRG1
# 26      K-SPACE ENERGY SPECTRUM ANALYSIS FOR ECHO-PLAN...          ZRG1
# 27      AN INTEGRATED SYSTEM FOR IMAGE-GUIDED RADIOFRE...          ZRG1
# 28      NATIONAL ALLIANCE-MEDICAL IMAGING COMPUTING (N...          ZRG1
# 29      A Carolina Center to Characterize &Maintain Mu...          ZRR1
# ...                                                   ...           ...
# 645409  Self-Management Pilot/Feasibility and Biobehav...          ZNR1
# 645410  Data Analysis, Research Program Development an...          ZNR1
# 645411                        Scholarship &Mentoring Core          ZNR1
# 645412                          Methods &Statistical Core          ZNR1
# 645413                    Dissemination &Translation Core          ZNR1
# 645414  Self-Management, Biobehavioral and Informatics...          ZNR1
# 645415  Design, Methods, Biostatistics, and Economic A...          ZNR1
# 645416                 Dissemination and Translation Core          ZNR1
# 645417       Nursing and Health Research Informatics Core          ZNR1
# 645418                        Mixed Methods Research Core          ZNR1
# 645419  Enhanced self-efficacy training for informal c...          ZNR1
# 645420  Uncertainty management in patients awaiting li...          ZNR1
# 645421  Outlook-an intervention to improve quality of ...          ZNR1
# 645422  Data collection, management and qualitative an...          ZNR1
# 645423  A routinization intervention to improve adhere...          ZNR1
# 645424  Self-efficacy based treatment for long-term we...          ZNR1
# 645425       Concordance therapy and medication adherence          ZNR1
# 645426  Strategies to improve caregiver mediated medic...          ZNR1
# 645427                         Translational support core          ZNR1
# 645428                                         Admin Core          ZNR1
# 645429  Self-Management Pilot/Feasibility and Biobehav...          ZNR1
# 645430  Data Analysis, Research Program Development an...          ZNR1
# 645431                        Scholarship &Mentoring Core          ZNR1
# 645432                          Methods &Statistical Core          ZNR1
# 645433                    Dissemination &Translation Core          ZNR1
# 645434  Self-Management, Biobehavioral and Informatics...          ZNR1
# 645435  Design, Methods, Biostatistics, and Economic A...          ZNR1
# 645436                 Dissemination and Translation Core          ZNR1
# 645437       Nursing and Health Research Informatics Core          ZNR1
# 645438                        Mixed Methods Research Core          ZNR1
#
#        SUBPROJECT_ID  SUFFIX  TOTAL_COST TOTAL_COST_SUB_PROJECT  \
# 0                NaN     NaN    741430.0                    NaN
# 1                NaN     NaN   1811959.0                    NaN
# 2                NaN      A1   1431792.0                    NaN
# 3                NaN      A1   1908805.0                    NaN
# 4                NaN     NaN   2067808.0                    NaN
# 5                NaN     NaN   3672199.0                    NaN
# 6                NaN      S1    160000.0                    NaN
# 7             7592.0     NaN         NaN              1836100.0
# 8             7593.0     NaN         NaN               160000.0
# 9             7594.0     NaN         NaN              1836099.0
# 10               NaN     NaN   2817101.0                    NaN
# 11            5850.0     NaN         NaN               443694.0
# 12            5851.0     NaN         NaN               646243.0
# 13            5852.0     NaN         NaN               149587.0
# 14            5853.0     NaN         NaN               485950.0
# 15            5854.0     NaN         NaN               505388.0
# 16            5855.0     NaN         NaN                28171.0
# 17            5856.0     NaN         NaN                28171.0
# 18            5857.0     NaN         NaN                28171.0
# 19            5858.0     NaN         NaN                28171.0
# 20            5859.0     NaN         NaN                28171.0
# 21            5860.0     NaN         NaN                28171.0
# 22            5861.0     NaN         NaN                28171.0
# 23            5862.0     NaN         NaN               169026.0
# 24            5863.0     NaN         NaN                79161.0
# 25            5864.0     NaN         NaN                56342.0
# 26            5865.0     NaN         NaN                28171.0
# 27            5866.0     NaN         NaN                28171.0
# 28            5867.0     NaN         NaN                28171.0
# 29               NaN      S2     57845.0                    NaN
# ...              ...     ...         ...                    ...
# 645409        9001.0     NaN         NaN                98977.0
# 645410        9002.0     NaN         NaN                90412.0
# 645411        9001.0     NaN         NaN                54797.0
# 645412        9002.0     NaN         NaN               169843.0
# 645413        9003.0     NaN         NaN                90016.0
# 645414        9001.0     NaN         NaN               218673.0
# 645415        9002.0     NaN         NaN               121764.0
# 645415                    Arthritis    0.996804
# 645416        Organ Transplantation    0.999896
# 645417               Bioengineering    0.999993
# 645418              Health Services    0.997842
# 645419                Mind and Body    0.999993
# 645420                Mind and Body    0.999993
# 645421                Mind and Body    0.999993
# 645422                Mind and Body    0.999993
# 645423    Major Depressive Disorder    1.000000
# 645424    Major Depressive Disorder    1.000000
# 645425    Major Depressive Disorder    1.000000
# 645426    Major Depressive Disorder    1.000000
# 645427    Major Depressive Disorder    1.000000
# 645428               Rehabilitation    0.999946
# 645429               Rehabilitation    0.999647
# 645430                       Asthma    0.999994
# 645431                 Rural Health    0.999964
# 645432  Cost Effectiveness Research    0.997652
# 645433                     Dementia    0.999921
# 645434                      Obesity    0.998345
# 645435                    Arthritis    0.996804
# 645436        Organ Transplantation    0.999896
# 645437                     Genetics    1.000000
# 645438               Bioengineering    0.997348
#
# [645439 rows x 40 columns]

# %%
funded_R01_projects_complete.to_csv("funded_R01_projects_with_categories.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-0e09dca3bb9c> in <module>()
# ----> 1 funded_R01_projects_complete.to_csv("funded_R01_projects_with_categories.csv")
#
# ~/anaconda3/envs/capstone/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~/anaconda3/envs/capstone/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     164                                          encoding=encoding,
#     165                                          compression=self.compression)
# --> 166                 f.write(buf)
#     167                 f.close()
#     168                 for _fh in handles:
#
# OSError: [Errno 22] Invalid argument

# %%
funded_R01_projects_complete.to_csv("data/funded_R01_projects_category.csv", chunksize = 1000)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-5f67762c0619> in <module>()
# ----> 1 funded_R01_projects_complete.to_csv("data/funded_R01_projects_category.csv", chunksize = 1000)
#
# ~/anaconda3/envs/capstone/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~/anaconda3/envs/capstone/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     164                                          encoding=encoding,
#     165                                          compression=self.compression)
# --> 166                 f.write(buf)
#     167                 f.close()
#     168                 for _fh in handles:
#
# OSError: [Errno 22] Invalid argument

# %%
funded_R01_projects_complete.to_pickle("data/funded_R01_projects_category.pkl")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-4f7655156749> in <module>()
# ----> 1 funded_R01_projects_complete.to_pickle("data/funded_R01_projects_category.pkl")
#
# ~/anaconda3/envs/capstone/lib/python3.6/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol)
#    2187         from pandas.io.pickle import to_pickle
#    2188         return to_pickle(self, path, compression=compression,
# -> 2189                          protocol=protocol)
#    2190
#    2191     def to_clipboard(self, excel=True, sep=None, **kwargs):
#
# ~/anaconda3/envs/capstone/lib/python3.6/site-packages/pandas/io/pickle.py in to_pickle(obj, path, compression, protocol)
#      75         protocol = pkl.HIGHEST_PROTOCOL
#      76     try:
# ---> 77         f.write(pkl.dumps(obj, protocol=protocol))
#      78     finally:
#      79         for _f in fh:
#
# OSError: [Errno 22] Invalid argument

# %%
[funded_R01_projects_complete_1, funded_R01_projects_complete_2] = np.array_split(funded_R01_projects_complete, 2)

# %%
df_list = [funded_R01_projects_complete_1, funded_R01_projects_complete_2]
df_names = ["funded_R01_projects_complete_1", "funded_R01_projects_complete_2"]

# %%
for name, df in zip(df_names, df_list):
    df.to_csv('data/{}.csv'.format(name), index = False)
